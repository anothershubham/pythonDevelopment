# %%
import seaborn as sns
sns.set()
sns.set(style='darkgrid')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
fileData = pd.read_csv('/Users/aletheadevelopmentteam/Downloads/Data_Visualization_with_Matplotlib/bigmart_data.csv')
fileData=fileData.dropna()
fileData.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
sns.lineplot('Item_Weight','Item_MRP',data= fileData[:50])

# %%
sns.barplot('Item_Type','Item_MRP',data= fileData[:5], ci=68, capsize=.2)

# %%
sns.distplot(fileData['Item_MRP'])

# %%
sns.boxplot(fileData['Item_MRP'], orient='h')

# %%
sns.violinplot(fileData['Item_MRP'], orient='h')

# %%
sns.catplot('Item_MRP', kind='violin', data=fileData)
