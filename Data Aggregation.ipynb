# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('/Users/aletheadevelopmentteam/Downloads/Apply function/bigmart_data.csv')

# %%
file[:5]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
file.dropna(inplace=True)
file.reset_index(drop=True, inplace=True)
file.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           NCD19        8.930          Low Fat         0.000000
# 4           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 3     Household   53.8614            OUT013                       1987
# 4  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
grouped1 = file.groupby(['Item_Type','Item_Fat_Content'])

# %%
grouped1.first()
# Out:
#                                Item_Identifier  Item_Weight  Item_Visibility  \
# Item_Type     Item_Fat_Content
# Baking Goods  LF                         FDP24       20.600         0.083133
#               Low Fat                    FDG24        7.975         0.014619
#               Regular                    FDP36       10.395         0.000000
#               low fat                    FDK48        7.445         0.000000
#               reg                        FDT24       12.350         0.186148
# ...                                        ...          ...              ...
# Starchy Foods LF                         FDB11       16.000         0.060797
#               Low Fat                    FDB11       16.000         0.060837
#               Regular                    FDB35       12.300         0.064565
#               low fat                    FDE47       14.150         0.037877
#               reg                        FDF11       10.195         0.017703
#
# ...

# %%
pd.crosstab(file['Outlet_Size'],file['Outlet_Type'],margins=True)
# Out:
# Outlet_Type  Supermarket Type1  Supermarket Type2   All
# Outlet_Size
# High                       932                  0   932
# Medium                     930                928  1858
# Small                     1860                  0  1860
# All                       3722                928  4650

# %%
file.pivot(columns='Outlet_Size', values='Outlet_Type')
# Out:
# Outlet_Size               High             Medium              Small
# 0                          NaN  Supermarket Type1                NaN
# 1                          NaN  Supermarket Type2                NaN
# 2                          NaN  Supermarket Type1                NaN
# 3            Supermarket Type1                NaN                NaN
# 4                          NaN  Supermarket Type2                NaN
# ...                        ...                ...                ...
# 4645                       NaN                NaN  Supermarket Type1
# 4646         Supermarket Type1                NaN                NaN
# 4647                       NaN                NaN  Supermarket Type1
# 4648                       NaN  Supermarket Type2                NaN
# 4649                       NaN                NaN  Supermarket Type1
#
# [4650 rows x 3 columns]

# %%
file.pivot_table(index='Outlet_Size',columns='Outlet_Type',fill_value=0, aggfunc=np.mean, margins=True)
# Out:
#                      Item_MRP                               Item_Outlet_Sales  \
# Outlet_Type Supermarket Type1 Supermarket Type2         All Supermarket Type1
# Outlet_Size
# High               141.425982          0.000000  141.425982       2298.995256
# Medium             140.297699        141.678634  140.987423       2348.354635
# Small              142.589934          0.000000  142.589934       2358.343066
# All                141.725726        141.678634  141.716328       2340.986430
#
#                                              Item_Visibility  \
# Outlet_Type Supermarket Type2          All Supermarket Type1
# Outlet_Size
# High                 0.000000  2298.995256          0.059957
# Medium            1995.498739  2172.116599          0.060806
# Small                0.000000  2358.343066          0.060864
# All               1995.498739  2272.037489          0.060622
#
#                                               Item_Weight                    \
# ...

# %%
file.pivot_table(index=['Outlet_Size','Outlet_Location_Type'],columns=['Outlet_Type','Outlet_Location_Type'],fill_value=0, aggfunc=np.mean, margins=True)
# Out:
#                                           Item_MRP                          \
# Outlet_Type                      Supermarket Type1
# Outlet_Location_Type                        Tier 1      Tier 2      Tier 3
# Outlet_Size Outlet_Location_Type
# High        Tier 3                        0.000000    0.000000  141.425982
# Medium      Tier 1                      140.297699    0.000000    0.000000
#             Tier 3                        0.000000    0.000000    0.000000
# Small       Tier 1                      142.057387    0.000000    0.000000
#             Tier 2                        0.000000  143.122481    0.000000
# All                                     141.177543  143.122481  141.425982
#
#                                                                 \
# Outlet_Type                      Supermarket Type2         All
# Outlet_Location_Type                        Tier 3
# Outlet_Size Outlet_Location_Type
# High        Tier 3                        0.000000  141.425982
# ...
